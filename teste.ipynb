# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

df1 = pd.read_csv("Experimento-1.csv")

df1
# Out:
#      Initial    Final Cost Function Algorithm  Objective Found  Path Cost  \
# 0     (29,3)  (27,20)            c1       DFS             True       1010
# 1     (29,3)  (27,20)            c1       BFS             True        190
# 2     (29,3)  (27,20)            c1  Dijkstra             True        190
# 3     (29,3)  (27,20)            c2       DFS             True       1030
# 4     (29,3)  (27,20)            c2       BFS             True        200
# ..       ...      ...           ...       ...              ...        ...
# 595  (26,17)    (5,8)            c3       BFS             True        351
# 596  (26,17)    (5,8)            c3  Dijkstra             True        330
# 597  (26,17)    (5,8)            c4       DFS             True       6742
# 598  (26,17)    (5,8)            c4       BFS             True        287
# 599  (26,17)    (5,8)            c4  Dijkstra             True        265
#
#      Generated Nodes  Visited Nodes
# 0                368            102
# ...

# %%
df2 = pd.read_csv("Experimento-2.csv")

df2.Heuristic.fillna("None", inplace=True)

df2
# Out:
#     Initial    Final Cost Function Algorithm  Objective Found  Path Cost  \
# 0    (21,5)   (15,7)            c1  Dijkstra             True         80
# 1    (21,5)   (15,7)            c1         A             True         80
# 2    (21,5)   (15,7)            c1         A             True         80
# 3    (21,5)   (15,7)            c2  Dijkstra             True        110
# 4    (21,5)   (15,7)            c2         A             True        110
# ..      ...      ...           ...       ...              ...        ...
# 595  (4,29)  (26,25)            c3         A             True        302
# 596  (4,29)  (26,25)            c3         A             True        302
# 597  (4,29)  (26,25)            c4  Dijkstra             True        227
# 598  (4,29)  (26,25)            c4         A             True        232
# 599  (4,29)  (26,25)            c4         A             True        231
#
#      Generated Nodes  Visited Nodes Heuristic
# ...

# %%
df3 = pd.read_csv("Experimento-3.csv")

df3
# Out:
#     Initial    Final Cost Function Algorithm  Objective Found  Path Cost  \
# 0    (18,4)   (4,15)            c1      GBFS             True        250
# 1    (18,4)   (4,15)            c1         A             True        250
# 2    (18,4)   (4,15)            c2      GBFS             True        320
# 3    (18,4)   (4,15)            c2         A             True        320
# 4    (18,4)   (4,15)            c3      GBFS             True        276
# ..      ...      ...           ...       ...              ...        ...
# 795  (28,7)  (30,18)            c2         A             True        140
# 796  (28,7)  (30,18)            c3      GBFS             True        135
# 797  (28,7)  (30,18)            c3         A             True        130
# 798  (28,7)  (30,18)            c4      GBFS             True        135
# 799  (28,7)  (30,18)            c4         A             True        129
#
#      Generated Nodes  Visited Nodes Heuristic
# ...

# %%
df4 = pd.read_csv("Experimento-4.csv")

df4
